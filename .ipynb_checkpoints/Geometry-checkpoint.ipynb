# %%
import ase
from ase.build import graphene_nanoribbon
from ase.cluster import Icosahedron
import py3Dmol
import io
print("Building components...")
# Out:
# Building components...

# %%
# Create the Carbon Flake
flake = graphene_nanoribbon(4,4, type ='armchair',saturated=True,vacuum=5.0)
#Create the Iron Catalyst Cluster(Fe13)
fe13 = Icosahedron('Fe', noshells=2, latticeconstant=2.52)

# %%
#Create the FeCl3 Vapor Molecule
fecl3 =ase.Atoms('FeCl3',positions=[[0.0, 0.0, 0.0],       # Fe
                             [2.14, 0.0, 0.0],      # Cl 1
                             [-1.07, 1.853, 0.0],   # Cl 2
                             [-1.07, -1.853, 0.0]])#Cl3

# %%
flake.center(about=(0., 0., 0.))
fe13.center(about=(0., 0., 0.))
fecl3.center(about=(0., 0., 0.))

# %%
# Stack them vertically: 
# Place the Fe13 cluster 2.5 Angstroms above the carbon flake.
# Place the FeCl3 molecule 4.0 Angstroms above the Fe13 cluster.
fe13.positions[:, 2] += 2.5
fecl3.positions[:, 2] += (2.5 + 4.0)
combined_system = flake + fe13 + fecl3

# %%
# 6. Visualize with py3Dmol
xyz_file = io.StringIO()
ase.io.write(xyz_file, combined_system, format='xyz')
xyz_data = xyz_file.getvalue()
viewer = py3Dmol.view(width=800, height=500)
viewer.addModel(xyz_data, 'xyz')
viewer.setStyle({'sphere': {'scale': 0.25}, 'stick': {'radius': 0.1}})
viewer.zoomTo()
viewer.show()
# Out:
# <div id="3dmolviewer_1781428919604247"  style="position: relative; width: 800px; height: 500px;">
#         <p id="3dmolwarning_1781428919604247" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.4/build/3Dmol-min.js');
# }
#
# var viewer_1781428919604247 = null;
# var warn = document.getElementById("3dmolwarning_1781428919604247");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_1781428919604247 = $3Dmol.createViewer(document.getElementById("3dmolviewer_1781428919604247"),{backgroundColor:"white"});
# viewer_1781428919604247.zoomTo();
# 	viewer_1781428919604247.addModel("97\n\nC       3.074390183434758      0.000000000000000     -7.810000000000000\nC       4.304146256808661      0.000000000000000     -7.100000000000000\nC       4.304146256808661      0.000000000000000     -5.680000000000000\nC       3.074390183434758      0.000000000000000     -4.970000000000000\nC       3.074390183434758      0.000000000000000     -3.550000000000000\nC       4.304146256808661      0.000000000000000     -2.840000000000000\nC       4.304146256808661      0.000000000000000     -1.420000000000000\nC       3.074390183434758      0.000000000000000     -0.710000000000000\nC       3.074390183434758      0.000000000000000      0.710000000000000\nC       4.304146256808661      0.000000000000000      1.420000000000001\nC       4.304146256808661      0.000000000000000      2.839999999999999\nC       3.074390183434758      